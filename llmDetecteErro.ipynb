# %%
import google.generativeai as genai
import pandas as pd
import time

# Sua chave de API
GEMINI_API_KEY = 'AIzaSyA6bUw0fDpsOwlc8mzvF_-bMbedztg4ygM'

# %%
bd = pd.read_excel('conclusaoValidacaoRes.xlsx')

# %%
bd
# Out:
#                                                Redação  QtdeCaracteres  \
# 0    A grande importância dos caminhoneiros para o ...             506
# 1    O senhor e eu já estamos cientes do projeto de...             234
# 2    É de conhecimento geral dos brasileiros o quão...             745
# 3    Podemos perceber que a sociedade brasileira en...             429
# 4    Comenta-se que o ex presidente Lula ex-preside...             311
# ..                                                 ...             ...
# 545  É possível notar que o Brasil é um país com um...             258
# 546  As redes sociais tem fugido do seu papel socia...             568
# 547  A escola foi criada para trazer mais educação ...             352
# 548  Prolongada Promulgada pela ONU em 1948, a Decl...             432
# 549  Há, na pré-história, pinturas rupestres que re...             458
#
#                                            Intervencao  \
# 0    Porém, não seria mais inteligente se o preside...
# 1    Assim, Excelentíssimo Senhor, sugiro que o sen...
# 2    Tendo em vista o pedido de Impeachment e toman...
# 3    Desse modo, é necessário que o governo proporc...
# 4    Mediante a sintaxe, o Ministério Público Feder...
# ..                                                 ...
# 545  Portanto, a fim de valorizarmos ainda mais o p...
# 546  assim deve se manter as bases que sustenta o n...
# 547  Há projeto do governo para a educação, mas fal...
# 548  Contudo, a realidade é justamente o oposto e o...
# 549  Dessa forma, como uma primeira medida, pode-se...
#
#      QtdeSentencasIntervencao  PorcentagemCaracteresIntervencao
# 0                           2                             22.98
# 1                           2                             16.36
# 2                           4                             28.85
# 3                           1                             30.56
# 4                           1                             24.05
# ..                        ...                               ...
# 545                         2                             20.64
# 546                         2                             29.77
# 547                         1                             33.56
# 548                         4                             39.17
# 549                         3                             16.79
#
# [550 rows x 5 columns]

# %%
genai.configure(api_key=GEMINI_API_KEY)

# Selecionar o modelo Gemini 1.5 Flash
model = genai.GenerativeModel('gemini-1.5-flash')

def gerar_prompt_conclusao(texto):
    return f"""
Você é um analisador de redações. Sua tarefa é identificar **apenas o trecho da conclusão** da redação abaixo.  
A conclusão geralmente está no final do texto e contém uma proposta de intervenção, uma síntese ou um fechamento argumentativo.  

Importante:
- Você deve **copiar exatamente o trecho original do texto**, sem alterar nenhuma palavra, pontuação ou formatação.
- Retorne **somente o trecho da conclusão**, não explique nada.

Redação:
\"\"\"{texto}\"\"\"

Resposta (apenas o trecho da conclusão, idêntico ao original):
"""

testeLLM = []

for i, row in bd.iterrows():
    questao = row["Redação"]
    prompt = gerar_prompt_conclusao(questao)
    
    try:
        response = model.generate_content(prompt)
        output = response.text.strip()
        print(f"[{i}] {output}\n")

        testeLLM.append(output)
        
    except Exception as e:
        print(f"Erro na questão {i}: {e}")
        testeLLM.append("erro")
    
    time.sleep(4)  

# Salvar resultado no dataframe
bd["testeLLM"] = testeLLM
# Out:
# [0] Porém, não seria mais inteligente se o presidente investisse novamente no transporte por ferrovias? A malha ferroviária possui baixo custo de frete, baixa taxa de poluição ambiental, baixo custo de manutenção, isenção de pedágios e o transporte ocorre de forma mais rápida e segura.Com isso, o governo teria um maior retorno monetário e a população pagaria menos impostos pelos produtos, fazendo assim com que fosse desnecessário prejudicar ainda mais o investimento em educação e saúde pública brasileira.
#
# [12] Para amenizar ambas as partes prejudicadas predudicadas, é importante manter os habitates sobre proteção responsavél responsável com avisos espalhados de riscos e manter a distância e aderir alguma maneira de pelo menos alimentar os ursos, tal como espalhar alimentos derivados a eles ao redor do hábitate habitat deles. Assim diminuir ou prolongar tragédias maiores que a estão surgindo. Desejando a volta da melhoria Climática climática.
#
# [13] """Eu acredito que os dois são muito importantes e um complementa o outro."""
#
# [14] Dado o explícito cenário, a consideração destes aspectos é relevante para que o governo faça uma fiscalização e avaliação para ver se deve ou não ser aperfeiçoado e desenvolvido ainda no século atual.
#
# [15] A Amazônia pertence ao Brasil e não é território internacional, sendo assim, benéfica ao mundo a partir do momento em que é preservada, sem deixar também de ser corretamente explorada para benefício econômico somente para o Brasil, da mesma forma que seria feito, talvez até de forma indiscriminada por nações hipócritas.
#
# [16] Tal crescimento nos números de obesos e com sobrepeso deve ser combatido com medidas positivas da Organização Mundial de Saúde (OMS) e do Governo como um todo, impondo restrições qualitativas e quantitativas às indústrias alimentícias, promovendo reeducação alimentar nas escolas e apoio nutricional completo pelo Sistema Único de Saúde (SUS). Assim, aos poucos, a população vai reaprendendo e se readaptando às suas atuais necessidades alimentares.
#
# [17] Dessarte o Estado não pode impor restrições à liberdade individual de sua população com a desculpa de estar prezando pela saúde dos cidadãos, pois as consequências são muito piores. O consumo e comércio de drogas deve ser regulamentado e junto a isso deve haver uma forte campanha alertando sobre os riscos do consumo dessas substâncias, como vem ocorrendo com o tabaco a muitos anos e mostrando resultados.
#
# [18] No entanto, isso precisa ser encarado como estímulo para aperfeiçoamento das teorias existentes e descoberta das descobertas de novas fórmulas para a contribuir com o bem-estar social. Com isso, serão garantidos tanto a liberdade de expressão quanto o desenvolvimento científico, que são protegidos pela Carta Magna.
#
# [19] Espero que esta carta tenha alcançado seu objetivo; esclarecer a vosso leitor qual a melhor forma de debater novas concepções com argumentações concretas e respeito ao próximo.
#
# [20] Devemos olhar o Brasil como um todo e não partido A ou B. Assim, o que se vê são brasileiros em casa partidários achando que um partido A estava roubando se manifestaram e colocaram o partido B e tudo está resolvido, sendo que estamos vendo é uma explosão de delações com provas e mais provas e os brasileiros inertes, afinal em 2015 tiramos os corruptos do país.
#
# [21] Sob essa ótica, cabe ao Poder Público garantir que esse grupo de pessoas, com menor poder aquisitivo, tenha acesso a tais tecnologias. Dessa forma, todos, sem distinção, poderão usufruir das inovações e benefícios que a tecnologia proporciona ao mundo contemporâneo.
#
# [22] Já foram 30 anos com tantos viciados deixados a sua própria vontade, passou da hora do Estado tomar medidas mais bruscas , como a internação compulsória.
#
# [23] Com isso, a família e a escola que juntas são responsável pela formação das futuras gerações tem que ser reeducada passar para as futuras gerações a ideia correta de beleza, mostra as crianças o que é realmente importante, para que elas não sejam manipuladas nem virem consumista , ou seja, desenvolvam a criticidade para serem cidadãos conscientes de suas escolas e ações.Consequentemente, seguir padrões de beleza pode causar sérios problemas, ter saúde e se sentir bem é o mais importante, cada pessoa deve criar seu próprio padrão de beleza.
#
# [143] Dessa forma, para que a natureza animal possa se manter em seu ambiente natural garantindo sua sobrevivência, é preciso que os governos, as pessoas, pratiquem atos de preservação do planeta, seja fazendo uso sustentável dos recursos naturais e industrializáveis, seja criando leis, campanhas, qualquer leis e campanhas. Qualquer atitude em prol da preservação ambiental é válida, mas é preciso agir logo, as consequências já são visíveis.
#
# ...
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Erro na questão 527: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Erro na questão 528: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Erro na questão 529: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Erro na questão 530: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Erro na questão 531: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# Erro na questão 532: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Erro na questão 533: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Erro na questão 534: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Erro na questão 535: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Erro na questão 536: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Erro na questão 537: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Erro na questão 538: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Erro na questão 539: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Erro na questão 540: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Erro na questão 541: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Erro na questão 542: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Erro na questão 543: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Erro na questão 544: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# Erro na questão 545: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
# Erro na questão 546: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# Erro na questão 547: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Erro na questão 548: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Erro na questão 549: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]

# %%
bd
# Out:
#                                                Redação  QtdeCaracteres  \
# 0    A grande importância dos caminhoneiros para o ...             506
# 1    O senhor e eu já estamos cientes do projeto de...             234
# 2    É de conhecimento geral dos brasileiros o quão...             745
# 3    Podemos perceber que a sociedade brasileira en...             429
# 4    Comenta-se que o ex presidente Lula ex-preside...             311
# ..                                                 ...             ...
# 545  É possível notar que o Brasil é um país com um...             258
# 546  As redes sociais tem fugido do seu papel socia...             568
# 547  A escola foi criada para trazer mais educação ...             352
# 548  Prolongada Promulgada pela ONU em 1948, a Decl...             432
# 549  Há, na pré-história, pinturas rupestres que re...             458
#
#                                            Intervencao  \
# 0    Porém, não seria mais inteligente se o preside...
# 1    Assim, Excelentíssimo Senhor, sugiro que o sen...
# 2    Tendo em vista o pedido de Impeachment e toman...
# 3    Desse modo, é necessário que o governo proporc...
# 4    Mediante a sintaxe, o Ministério Público Feder...
# ..                                                 ...
# 545  Portanto, a fim de valorizarmos ainda mais o p...
# 546  assim deve se manter as bases que sustenta o n...
# 547  Há projeto do governo para a educação, mas fal...
# 548  Contudo, a realidade é justamente o oposto e o...
# 549  Dessa forma, como uma primeira medida, pode-se...
#
#      QtdeSentencasIntervencao  PorcentagemCaracteresIntervencao  \
# 0                           2                             22.98
# 1                           2                             16.36
# 2                           4                             28.85
# 3                           1                             30.56
# 4                           1                             24.05
# ..                        ...                               ...
# 545                         2                             20.64
# 546                         2                             29.77
# 547                         1                             33.56
# 548                         4                             39.17
# 549                         3                             16.79
#
#                                               testeLLM
# 0    Porém, não seria mais inteligente se o preside...
# 1    Assim, Excelentíssimo Senhor, sugiro que o sen...
# 2    Tendo em vista o pedido de Impeachment e toman...
# 3    Desse modo, é necessário que o governo proporc...
# 4    Medianta a sintaxe, o Ministério Público Feder...
# ..                                                 ...
# 545                                               erro
# 546                                               erro
# 547                                               erro
# 548                                               erro
# 549                                               erro
#
# [550 rows x 6 columns]

# %%
bd[bd["testeLLM"] != bd["Intervencao"]]
# Out:
#                                                Redação  QtdeCaracteres  \
# 4    Comenta-se que o ex presidente Lula ex-preside...             311
# 5    É notório como notícias envolvendo o homossexu...             261
# 8    Há alguns meses atrás , ocorreu um evento que ...             522
# 9    Amazonas, sem ela ele os dias do brasil Brasil...             330
# 10   Eu sou jovem, mas não faço parte da "geração e...             329
# ..                                                 ...             ...
# 545  É possível notar que o Brasil é um país com um...             258
# 546  As redes sociais tem fugido do seu papel socia...             568
# 547  A escola foi criada para trazer mais educação ...             352
# 548  Prolongada Promulgada pela ONU em 1948, a Decl...             432
# 549  Há, na pré-história, pinturas rupestres que re...             458
#
#                                            Intervencao  \
# 4    Mediante a sintaxe, o Ministério Público Feder...
# 5    Destarte, a sociedade deve compreender o senti...
# 8    Portanto, a afirmação de que esses direitos só...
# 9    Mas, com esse incêndio, muitos estados de outr...
# 10   Quando se pensa em si ignorando que mais pesso...
# ..                                                 ...
# 545  Portanto, a fim de valorizarmos ainda mais o p...
# 546  assim deve se manter as bases que sustenta o n...
# 547  Há projeto do governo para a educação, mas fal...
# 548  Contudo, a realidade é justamente o oposto e o...
# 549  Dessa forma, como uma primeira medida, pode-se...
#
#      QtdeSentencasIntervencao  PorcentagemCaracteresIntervencao  \
# 4                           1                             24.05
# 5                           2                             11.53
# 8                           3                             29.26
# 9                           1                             38.96
# 10                          3                             36.39
# ..                        ...                               ...
# 545                         2                             20.64
# 546                         2                             29.77
# 547                         1                             33.56
# 548                         4                             39.17
# 549                         3                             16.79
#
#                                               testeLLM
# 4    Medianta a sintaxe, o Ministério Público Feder...
# 5    Sendo assim, é de suma importância a placidez ...
# 8    São as pessoas que mudam o seu país, e em um a...
# 9    mais mas uma coisa é certa logo esse incêndio ...
# 10   Não sou da "geração eu", pois tomo as minhas d...
# ..                                                 ...
# 545                                               erro
# 546                                               erro
# 547                                               erro
# 548                                               erro
# 549                                               erro
#
# [372 rows x 6 columns]

# %%
# Função para aplicar destaque amarelo na linha se for diferente
def highlight_diferenca(row):
    if row["testeLLM"] != row["Intervencao"]:
        return ['background-color: yellow'] * len(row)
    else:
        return [''] * len(row)

# Aplica o estilo
styled = bd.style.apply(highlight_diferenca, axis=1)

# %%
from nltk.tokenize import sent_tokenize

def preencher_tabela(bd):
    dados = []

    for i ,row in bd.iterrows():        
        QtdeCaracteres = len(row['testeLLM'])
        qtde_frases = len(sent_tokenize(row['testeLLM'], language='portuguese'))
        porcentagem = round((len(row['testeLLM']) / len(row['Redação'])) * 100, 2) if len(row['Redação']) > 0 else 0

        dados.append({
            'QtdeCaracteresLLM': QtdeCaracteres,
            'QtdeSentencasIntervencaoLLM': qtde_frases,
            'PorcentagemCaracteresIntervencaoLLM': porcentagem
        })

    return pd.DataFrame(dados)

# %%
dados = preencher_tabela(bd)

# %%
dados
# Out:
#      QtdeCaracteresLLM  QtdeSentencasIntervencaoLLM  \
# 0                  506                            2
# 1                  234                            2
# 2                  745                            4
# 3                  429                            1
# 4                  311                            1
# ..                 ...                          ...
# 545                  4                            1
# 546                  4                            1
# 547                  4                            1
# 548                  4                            1
# 549                  4                            1
#
#      PorcentagemCaracteresIntervencaoLLM
# 0                                  22.98
# 1                                  16.36
# 2                                  28.85
# 3                                  30.56
# 4                                  24.05
# ..                                   ...
# 545                                 0.32
# 546                                 0.21
# 547                                 0.38
# 548                                 0.36
# 549                                 0.15
#
# [550 rows x 3 columns]

# %%
bd = pd.read_excel('diferencas_destacadas.xlsx')

# %%
df= pd.concat([bd, dados], axis=1)

# %%
df
# Out:
#                                                Redação  QtdeCaracteres  \
# 0    A grande importância dos caminhoneiros para o ...             506
# 1    O senhor e eu já estamos cientes do projeto de...             234
# 2    É de conhecimento geral dos brasileiros o quão...             745
# 3    Podemos perceber que a sociedade brasileira en...             429
# 4    Comenta-se que o ex presidente Lula ex-preside...             311
# ..                                                 ...             ...
# 545  É possível notar que o Brasil é um país com um...             258
# 546  As redes sociais tem fugido do seu papel socia...             568
# 547  A escola foi criada para trazer mais educação ...             352
# 548  Prolongada Promulgada pela ONU em 1948, a Decl...             432
# 549  Há, na pré-história, pinturas rupestres que re...             458
#
#                                            Intervencao  \
# 0    Porém, não seria mais inteligente se o preside...
# 1    Assim, Excelentíssimo Senhor, sugiro que o sen...
# 2    Tendo em vista o pedido de Impeachment e toman...
# 3    Desse modo, é necessário que o governo proporc...
# 4    Mediante a sintaxe, o Ministério Público Feder...
# ..                                                 ...
# 545  Portanto, a fim de valorizarmos ainda mais o p...
# 546  assim deve se manter as bases que sustenta o n...
# 547  Há projeto do governo para a educação, mas fal...
# 548  Contudo, a realidade é justamente o oposto e o...
# 549  Dessa forma, como uma primeira medida, pode-se...
#
#      QtdeSentencasIntervencao  PorcentagemCaracteresIntervencao  \
# 0                           2                             22.98
# 1                           2                             16.36
# 2                           4                             28.85
# 3                           1                             30.56
# 4                           1                             24.05
# ..                        ...                               ...
# 545                         2                             20.64
# 546                         2                             29.77
# 547                         1                             33.56
# 548                         4                             39.17
# 549                         3                             16.79
#
#                                               testeLLM  QtdeCaracteresLLM  \
# 0    Porém, não seria mais inteligente se o preside...                506
# 1    Assim, Excelentíssimo Senhor, sugiro que o sen...                234
# 2    Tendo em vista o pedido de Impeachment e toman...                745
# 3    Desse modo, é necessário que o governo proporc...                429
# 4    Medianta a sintaxe, o Ministério Público Feder...                311
# ..                                                 ...                ...
# 545                                               erro                  4
# 546                                               erro                  4
# 547                                               erro                  4
# 548                                               erro                  4
# 549                                               erro                  4
#
#      QtdeSentencasIntervencaoLLM  PorcentagemCaracteresIntervencaoLLM
# 0                              2                                22.98
# 1                              2                                16.36
# 2                              4                                28.85
# 3                              1                                30.56
# 4                              1                                24.05
# ..                           ...                                  ...
# 545                            1                                 0.32
# 546                            1                                 0.21
# 547                            1                                 0.38
# 548                            1                                 0.36
# 549                            1                                 0.15
#
# [550 rows x 9 columns]

# %%
# Salva com xlsxwriter mantendo o destaque
styled.to_excel("diferencas_destacadas01.xlsx", engine='xlsxwriter', index=False)
